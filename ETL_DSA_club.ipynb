# %%
#Extract Data
import pandas as pd

df = pd.read_csv('jobs.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Part-Time Work From Home as Data Contributor A...
# 1           1                           FRAG DEVELOPMENT MANAGER
# 2           2                          Associate Process Manager
# 3           3  SAP Security - Lead Solution Advisor/Senior So...
# 4           4                                   MP & L - Manager
#
#              company                              location          etc
# 0       TransPerfect     Vadodara, Gujarat, India (Remote)  2 weeks ago
# 1      dsm-firmenich  Mumbai, Maharashtra, India (On-site)     Promoted
# 2             eClerx  Mumbai, Maharashtra, India (On-site)     Promoted
# 3           Deloitte            Mumbai, Maharashtra, India     Promoted
# 4  Dana Incorporated   Mawal, Maharashtra, India (On-site)    1 day ago

# %%
#Transform Data:
df = df.dropna() #method is used to remove or drop the rows containing missing (NaN) values

#Convert a column to lowercase
df['title'] = df['title'].str.capitalize()
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0  Part-time work from home as data contributor a...
# 1           1                           Frag development manager
# 2           2                          Associate process manager
# 3           3  Sap security - lead solution advisor/senior so...
# 4           4                                   Mp & l - manager
#
#              company                              location          etc
# 0       TransPerfect     Vadodara, Gujarat, India (Remote)  2 weeks ago
# 1      dsm-firmenich  Mumbai, Maharashtra, India (On-site)     Promoted
# 2             eClerx  Mumbai, Maharashtra, India (On-site)     Promoted
# 3           Deloitte            Mumbai, Maharashtra, India     Promoted
# 4  Dana Incorporated   Mawal, Maharashtra, India (On-site)    1 day ago

# %%
import pandas as pd

# Define a custom transformation function that compresses consecutive characters
def custom_transform(value):
    compressed_str = ""
    count = 1

    # Iterate through each character in the string
    for i in range(1, len(value)):

        # Check if the current character is the same as the previous one
        if value[i] == value[i - 1]:

            # If yes, increment the count for consecutive characters
            count += 1

        else:
            # If not, append the previous character and its count to the compressed string
            compressed_str += value[i - 1] + str(count)

            # Reset count for a new character
            count = 1

    # Append the last character and its count to the compressed string
    compressed_str += value[-1] + str(count)

    return compressed_str
df['compressed_column'] = df['title'].apply(custom_transform)
print(df)
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Part-time work from home as data contributor a...
# 1            1                           Frag development manager
# 2            2                          Associate process manager
# 3            3  Sap security - lead solution advisor/senior so...
# 4            4                                   Mp & l - manager
# 5            5                                    Sales executive
# 6            6    Serviços para o hóspede — com detalhes pessoais
# 7            7                                        Manager-r&d
# 8            8                  State head-cross sell (sme loans)
# 9            9                    Gerente – com detalhes pessoais
# 10          10                                   Production agent
# 11          11                                   Factory incharge
# 12          12                                   Rme manager - ii
# 13          13                     Director, national sales, west
# 14          14        Sap for utilities crm application developer
# 15          15                               Manager - salesforce
# 16          16                                 Mgr, segment mgmt.
# 17          17  Assistant relationship manager – india market ...
# 18          18                   Manager - eddr - document review
# 19          19                                            Advisor
# 20          20                  Senior account executive, le, gts
# 21          21                                  Manager - indices
# 22          22  Director, solution consulting - public sector ...
# 23          23                      Team lead - technical academy
# 24          24                                          Head chef
# 25          25                               Receptionist fresher
# 26          26       Chief customer transformation advisor (ccta)
# 27          27       Team member - women empowerment ( 81151169 )
# 28          28                         Quality control supervisor
# 29          29                                          Cook-lead
# 30          30                                            Manager
# 31          31                       Manager - category (apparel)
# 32          32                                        Manager-gtm
# 33          33          Assistant manager - digital growth, lakme
# 34          34                                      Manager- fico
# 35          35                             People director, india
# 36          36                                          Sme - dns
# 37          37           Hiring senior manager - operations (pto)
# 38          38                                         Consultant
# 39          39          Manager, policy and sme climate hub india
# 40          40                        Business director - digital
# 41          41                                 Fashion consultant
# 42          42                                     Senior manager
# 43          43                                     Senior manager
# 44          44                                     Vice president
# 45          45                             Regional sales manager
# 46          46                                     Senior manager
# 47          47                              Vice president- sales
# 48          48                         Senior partner in strategy
#
#                           company                                   location  \
# 0                    TransPerfect          Vadodara, Gujarat, India (Remote)
# 1                   dsm-firmenich       Mumbai, Maharashtra, India (On-site)
# 2                          eClerx       Mumbai, Maharashtra, India (On-site)
# 3                        Deloitte                 Mumbai, Maharashtra, India
# 4               Dana Incorporated        Mawal, Maharashtra, India (On-site)
# 5                         Rooftop       Mumbai, Maharashtra, India (On-site)
# 6                   Hyatt Centric       Mumbai, Maharashtra, India (On-site)
# 7                    Godrej Group   Ulhasnagar, Maharashtra, India (On-site)
# 8                 IDFC FIRST Bank       Mumbai, Maharashtra, India (On-site)
# 9                     Hyatt Place               Maharashtra, India (On-site)
# 10                          Wipro       Mumbai, Maharashtra, India (On-site)
# 11  Disha Skill Training Services        Thane, Maharashtra, India (On-site)
# 12                         Amazon                    ₹30K/month - ₹35K/month
# 13         Marriott International                 Mumbai, Maharashtra, India
# 14             Accenture in India                 Mumbai, Maharashtra, India
# 15            General Mills India                 Mumbai, Maharashtra, India
# 16             Standard Chartered       Mumbai Metropolitan Region (On-site)
# 17                  Credit Suisse       Mumbai Metropolitan Region (On-site)
# 18                        Elevate                             India (Remote)
# 19                            WTW        Mumbai, Maharashtra, India (Hybrid)
# 20                        Gartner       Mumbai, Maharashtra, India (On-site)
# 21                 CRISIL Limited       Mumbai, Maharashtra, India (On-site)
# 22                     ServiceNow       Mumbai, Maharashtra, India (On-site)
# 23         Aditya Birla Chemicals        Worli, Maharashtra, India (On-site)
# 24                    Moxy Hotels                 Mumbai, Maharashtra, India
# 25         Marine Debt Management                             India (Remote)
# 26                     Salesforce                ₹25.4K/month - ₹32.4K/month
# 27    Reliance Industries Limited       Mumbai, Maharashtra, India (On-site)
# 28           Achievers Enterprise                             India (Remote)
# 29  Marriott Executive Apartments                    ₹30K/month - ₹40K/month
# 30                Bank of America                 Mumbai, Maharashtra, India
# 31                        FanCode               Borivali, Maharashtra, India
# 32                          Zycus       Mumbai, Maharashtra, India (On-site)
# 33                       Unilever        Mumbai, Maharashtra, India (Hybrid)
# 34                     SUN PHARMA       Mumbai, Maharashtra, India (On-site)
# 35                     Condé Nast                 Mumbai, Maharashtra, India
# 36    Jio Platforms Limited (JPL)  Navi Mumbai, Maharashtra, India (On-site)
# 37                 Hapag-Lloyd AG       Mumbai, Maharashtra, India (On-site)
# 38               Frost & Sullivan                 Mumbai Metropolitan Region
# 39     We Mean Business Coalition                             India (Remote)
# 40                EssenceMediacom       Mumbai, Maharashtra, India (On-site)
# 41       Nicobar Design Pvt. Ltd.       Mumbai Metropolitan Region (On-site)
# 42                Bank of America                 Mumbai, Maharashtra, India
# 43                Bank of America                 Mumbai, Maharashtra, India
# 44               3i Infotech Ltd.  Navi Mumbai, Maharashtra, India (On-site)
# 45               ColorTokens Inc.       Mumbai, Maharashtra, India (On-site)
# 46                        Fractal       Mumbai, Maharashtra, India (On-site)
# 47                Jeena & Company       Mumbai, Maharashtra, India (On-site)
# 48               Consulting Point       Mumbai, Maharashtra, India (On-site)
#
#                                        etc  \
# 0                              2 weeks ago
# 1                                 Promoted
# 2                                 Promoted
# 3                                 Promoted
# 4                                1 day ago
# 5                            23 applicants
# 6                                 Promoted
# 7   20 hours ago\nWithin the past 24 hours
# 8                                 Promoted
# 9                                 Promoted
# 10                            7 applicants
# 11                                Promoted
# 12                           11 applicants
# 13                              2 days ago
# 14                              1 week ago
# 15                           11 applicants
# 16                                Promoted
# 17                                Promoted
# 18                            6 applicants
# 19                                Promoted
# 20                              1 week ago
# 21                              1 week ago
# 22                                Promoted
# 23                                Promoted
# 24                              Easy Apply
# 25                                Promoted
# 26                            2 months ago
# 27                              Easy Apply
# 28                            2 months ago
# 29                              Easy Apply
# 30                                Promoted
# 31                            0 applicants
# 32                                Promoted
# 33                                Promoted
# 34                              1 week ago
# 35                                Promoted
# 36                                Promoted
# 37                              Easy Apply
# 38                                Promoted
# 39                                Promoted
# 40                                Promoted
# 41                              Easy Apply
# 42                                Promoted
# 43                           14 applicants
# 44                                Promoted
# 45                                Promoted
# 46                              Easy Apply
# 47                                Promoted
# 48                              Easy Apply
#
#                                     compressed_column
# 0   P1a1r1t1-1t1i1m1e1 1w1o1r1k1 1f1r1o1m1 1h1o1m1...
# 1    F1r1a1g1 1d1e1v1e1l1o1p1m1e1n1t1 1m1a1n1a1g1e1r1
# 2      A1s2o1c1i1a1t1e1 1p1r1o1c1e1s2 1m1a1n1a1g1e1r1
# 3   S1a1p1 1s1e1c1u1r1i1t1y1 1-1 1l1e1a1d1 1s1o1l1...
# 4                    M1p1 1&1 1l1 1-1 1m1a1n1a1g1e1r1
# 5                      S1a1l1e1s1 1e1x1e1c1u1t1i1v1e1
# 6   S1e1r1v1i1ç1o1s1 1p1a1r1a1 1o1 1h1ó1s1p1e1d1e1...
# 7                              M1a1n1a1g1e1r1-1r1&1d1
# 8   S1t1a1t1e1 1h1e1a1d1-1c1r1o1s2 1s1e1l2 1(1s1m1...
# 9   G1e1r1e1n1t1e1 1–1 1c1o1m1 1d1e1t1a1l1h1e1s1 1...
# 10                   P1r1o1d1u1c1t1i1o1n1 1a1g1e1n1t1
# 11                   F1a1c1t1o1r1y1 1i1n1c1h1a1r1g1e1
# 12                     R1m1e1 1m1a1n1a1g1e1r1 1-1 1i2
# 13  D1i1r1e1c1t1o1r1,1 1n1a1t1i1o1n1a1l1 1s1a1l1e1...
# 14  S1a1p1 1f1o1r1 1u1t1i1l1i1t1i1e1s1 1c1r1m1 1a1...
# 15           M1a1n1a1g1e1r1 1-1 1s1a1l1e1s1f1o1r1c1e1
# 16               M1g1r1,1 1s1e1g1m1e1n1t1 1m1g1m1t1.1
# 17  A1s2i1s1t1a1n1t1 1r1e1l1a1t1i1o1n1s1h1i1p1 1m1...
# 18  M1a1n1a1g1e1r1 1-1 1e1d2r1 1-1 1d1o1c1u1m1e1n1...
# 19                                     A1d1v1i1s1o1r1
# 20  S1e1n1i1o1r1 1a1c2o1u1n1t1 1e1x1e1c1u1t1i1v1e1...
# 21                 M1a1n1a1g1e1r1 1-1 1i1n1d1i1c1e1s1
# 22  D1i1r1e1c1t1o1r1,1 1s1o1l1u1t1i1o1n1 1c1o1n1s1...
# 23  T1e1a1m1 1l1e1a1d1 1-1 1t1e1c1h1n1i1c1a1l1 1a1...
# 24                                 H1e1a1d1 1c1h1e1f1
# 25           R1e1c1e1p1t1i1o1n1i1s1t1 1f1r1e1s1h1e1r1
# 26  C1h1i1e1f1 1c1u1s1t1o1m1e1r1 1t1r1a1n1s1f1o1r1...
# 27  T1e1a1m1 1m1e1m1b1e1r1 1-1 1w1o1m1e1n1 1e1m1p1...
# 28  Q1u1a1l1i1t1y1 1c1o1n1t1r1o1l1 1s1u1p1e1r1v1i1...
# 29                                   C1o2k1-1l1e1a1d1
# 30                                     M1a1n1a1g1e1r1
# 31  M1a1n1a1g1e1r1 1-1 1c1a1t1e1g1o1r1y1 1(1a1p2a1...
# 32                             M1a1n1a1g1e1r1-1g1t1m1
# 33  A1s2i1s1t1a1n1t1 1m1a1n1a1g1e1r1 1-1 1d1i1g1i1...
# 34                         M1a1n1a1g1e1r1-1 1f1i1c1o1
# 35       P1e1o1p1l1e1 1d1i1r1e1c1t1o1r1,1 1i1n1d1i1a1
# 36                                 S1m1e1 1-1 1d1n1s1
# 37  H1i1r1i1n1g1 1s1e1n1i1o1r1 1m1a1n1a1g1e1r1 1-1...
# 38                               C1o1n1s1u1l1t1a1n1t1
# 39  M1a1n1a1g1e1r1,1 1p1o1l1i1c1y1 1a1n1d1 1s1m1e1...
# 40  B1u1s1i1n1e1s2 1d1i1r1e1c1t1o1r1 1-1 1d1i1g1i1...
# 41               F1a1s1h1i1o1n1 1c1o1n1s1u1l1t1a1n1t1
# 42                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 43                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 44                       V1i1c1e1 1p1r1e1s1i1d1e1n1t1
# 45       R1e1g1i1o1n1a1l1 1s1a1l1e1s1 1m1a1n1a1g1e1r1
# 46                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 47         V1i1c1e1 1p1r1e1s1i1d1e1n1t1-1 1s1a1l1e1s1
# 48  S1e1n1i1o1r1 1p1a1r1t1n1e1r1 1i1n1 1s1t1r1a1t1...

# %%
#Load Data:
#Save the transformed data to the desired target, which could be a different file format, a database, or another system.

jobs = 'transformed_data.csv'#saving the transformed datset to csv
df.to_csv(jobs, index=False)

loaded_df = pd.read_csv(jobs) #load the saved dataset into new DataFrame

'''Example: Load data into a database using SQLAlchemy
from sqlalchemy import create_engine

engine = create_engine('your_database_connection_string')
df.to_sql('table_name', engine, index=False, if_exists='replace')'''
# Out:
#     Unnamed: 0                                              title  \
# 0            0  Part-time work from home as data contributor a...
# 1            1                           Frag development manager
# 2            2                          Associate process manager
# 3            3  Sap security - lead solution advisor/senior so...
# 4            4                                   Mp & l - manager
# 5            5                                    Sales executive
# 6            6    Serviços para o hóspede — com detalhes pessoais
# 7            7                                        Manager-r&d
# 8            8                  State head-cross sell (sme loans)
# 9            9                    Gerente – com detalhes pessoais
# 10          10                                   Production agent
# 11          11                                   Factory incharge
# 12          12                                   Rme manager - ii
# 13          13                     Director, national sales, west
# 14          14        Sap for utilities crm application developer
# 15          15                               Manager - salesforce
# 16          16                                 Mgr, segment mgmt.
# 17          17  Assistant relationship manager – india market ...
# 18          18                   Manager - eddr - document review
# 19          19                                            Advisor
# 20          20                  Senior account executive, le, gts
# 21          21                                  Manager - indices
# 22          22  Director, solution consulting - public sector ...
# 23          23                      Team lead - technical academy
# 24          24                                          Head chef
# 25          25                               Receptionist fresher
# 26          26       Chief customer transformation advisor (ccta)
# 27          27       Team member - women empowerment ( 81151169 )
# 28          28                         Quality control supervisor
# 29          29                                          Cook-lead
# 30          30                                            Manager
# 31          31                       Manager - category (apparel)
# 32          32                                        Manager-gtm
# 33          33          Assistant manager - digital growth, lakme
# 34          34                                      Manager- fico
# 35          35                             People director, india
# 36          36                                          Sme - dns
# 37          37           Hiring senior manager - operations (pto)
# 38          38                                         Consultant
# 39          39          Manager, policy and sme climate hub india
# 40          40                        Business director - digital
# 41          41                                 Fashion consultant
# 42          42                                     Senior manager
# 43          43                                     Senior manager
# 44          44                                     Vice president
# 45          45                             Regional sales manager
# 46          46                                     Senior manager
# 47          47                              Vice president- sales
# 48          48                         Senior partner in strategy
#
#                           company                                   location  \
# 0                    TransPerfect          Vadodara, Gujarat, India (Remote)
# 1                   dsm-firmenich       Mumbai, Maharashtra, India (On-site)
# 2                          eClerx       Mumbai, Maharashtra, India (On-site)
# 3                        Deloitte                 Mumbai, Maharashtra, India
# 4               Dana Incorporated        Mawal, Maharashtra, India (On-site)
# 5                         Rooftop       Mumbai, Maharashtra, India (On-site)
# 6                   Hyatt Centric       Mumbai, Maharashtra, India (On-site)
# 7                    Godrej Group   Ulhasnagar, Maharashtra, India (On-site)
# 8                 IDFC FIRST Bank       Mumbai, Maharashtra, India (On-site)
# 9                     Hyatt Place               Maharashtra, India (On-site)
# 10                          Wipro       Mumbai, Maharashtra, India (On-site)
# 11  Disha Skill Training Services        Thane, Maharashtra, India (On-site)
# 12                         Amazon                    ₹30K/month - ₹35K/month
# 13         Marriott International                 Mumbai, Maharashtra, India
# 14             Accenture in India                 Mumbai, Maharashtra, India
# 15            General Mills India                 Mumbai, Maharashtra, India
# 16             Standard Chartered       Mumbai Metropolitan Region (On-site)
# 17                  Credit Suisse       Mumbai Metropolitan Region (On-site)
# 18                        Elevate                             India (Remote)
# 19                            WTW        Mumbai, Maharashtra, India (Hybrid)
# 20                        Gartner       Mumbai, Maharashtra, India (On-site)
# 21                 CRISIL Limited       Mumbai, Maharashtra, India (On-site)
# 22                     ServiceNow       Mumbai, Maharashtra, India (On-site)
# 23         Aditya Birla Chemicals        Worli, Maharashtra, India (On-site)
# 24                    Moxy Hotels                 Mumbai, Maharashtra, India
# 25         Marine Debt Management                             India (Remote)
# 26                     Salesforce                ₹25.4K/month - ₹32.4K/month
# 27    Reliance Industries Limited       Mumbai, Maharashtra, India (On-site)
# 28           Achievers Enterprise                             India (Remote)
# 29  Marriott Executive Apartments                    ₹30K/month - ₹40K/month
# 30                Bank of America                 Mumbai, Maharashtra, India
# 31                        FanCode               Borivali, Maharashtra, India
# 32                          Zycus       Mumbai, Maharashtra, India (On-site)
# 33                       Unilever        Mumbai, Maharashtra, India (Hybrid)
# 34                     SUN PHARMA       Mumbai, Maharashtra, India (On-site)
# 35                     Condé Nast                 Mumbai, Maharashtra, India
# 36    Jio Platforms Limited (JPL)  Navi Mumbai, Maharashtra, India (On-site)
# 37                 Hapag-Lloyd AG       Mumbai, Maharashtra, India (On-site)
# 38               Frost & Sullivan                 Mumbai Metropolitan Region
# 39     We Mean Business Coalition                             India (Remote)
# 40                EssenceMediacom       Mumbai, Maharashtra, India (On-site)
# 41       Nicobar Design Pvt. Ltd.       Mumbai Metropolitan Region (On-site)
# 42                Bank of America                 Mumbai, Maharashtra, India
# 43                Bank of America                 Mumbai, Maharashtra, India
# 44               3i Infotech Ltd.  Navi Mumbai, Maharashtra, India (On-site)
# 45               ColorTokens Inc.       Mumbai, Maharashtra, India (On-site)
# 46                        Fractal       Mumbai, Maharashtra, India (On-site)
# 47                Jeena & Company       Mumbai, Maharashtra, India (On-site)
# 48               Consulting Point       Mumbai, Maharashtra, India (On-site)
#
#                                        etc  \
# 0                              2 weeks ago
# 1                                 Promoted
# 2                                 Promoted
# 3                                 Promoted
# 4                                1 day ago
# 5                            23 applicants
# 6                                 Promoted
# 7   20 hours ago\nWithin the past 24 hours
# 8                                 Promoted
# 9                                 Promoted
# 10                            7 applicants
# 11                                Promoted
# 12                           11 applicants
# 13                              2 days ago
# 14                              1 week ago
# 15                           11 applicants
# 16                                Promoted
# 17                                Promoted
# 18                            6 applicants
# 19                                Promoted
# 20                              1 week ago
# 21                              1 week ago
# 22                                Promoted
# 23                                Promoted
# 24                              Easy Apply
# 25                                Promoted
# 26                            2 months ago
# 27                              Easy Apply
# 28                            2 months ago
# 29                              Easy Apply
# 30                                Promoted
# 31                            0 applicants
# 32                                Promoted
# 33                                Promoted
# 34                              1 week ago
# 35                                Promoted
# 36                                Promoted
# 37                              Easy Apply
# 38                                Promoted
# 39                                Promoted
# 40                                Promoted
# 41                              Easy Apply
# 42                                Promoted
# 43                           14 applicants
# 44                                Promoted
# 45                                Promoted
# 46                              Easy Apply
# 47                                Promoted
# 48                              Easy Apply
#
#                                     compressed_column
# 0   P1a1r1t1-1t1i1m1e1 1w1o1r1k1 1f1r1o1m1 1h1o1m1...
# 1    F1r1a1g1 1d1e1v1e1l1o1p1m1e1n1t1 1m1a1n1a1g1e1r1
# 2      A1s2o1c1i1a1t1e1 1p1r1o1c1e1s2 1m1a1n1a1g1e1r1
# 3   S1a1p1 1s1e1c1u1r1i1t1y1 1-1 1l1e1a1d1 1s1o1l1...
# 4                    M1p1 1&1 1l1 1-1 1m1a1n1a1g1e1r1
# 5                      S1a1l1e1s1 1e1x1e1c1u1t1i1v1e1
# 6   S1e1r1v1i1ç1o1s1 1p1a1r1a1 1o1 1h1ó1s1p1e1d1e1...
# 7                              M1a1n1a1g1e1r1-1r1&1d1
# 8   S1t1a1t1e1 1h1e1a1d1-1c1r1o1s2 1s1e1l2 1(1s1m1...
# 9   G1e1r1e1n1t1e1 1–1 1c1o1m1 1d1e1t1a1l1h1e1s1 1...
# 10                   P1r1o1d1u1c1t1i1o1n1 1a1g1e1n1t1
# 11                   F1a1c1t1o1r1y1 1i1n1c1h1a1r1g1e1
# 12                     R1m1e1 1m1a1n1a1g1e1r1 1-1 1i2
# 13  D1i1r1e1c1t1o1r1,1 1n1a1t1i1o1n1a1l1 1s1a1l1e1...
# 14  S1a1p1 1f1o1r1 1u1t1i1l1i1t1i1e1s1 1c1r1m1 1a1...
# 15           M1a1n1a1g1e1r1 1-1 1s1a1l1e1s1f1o1r1c1e1
# 16               M1g1r1,1 1s1e1g1m1e1n1t1 1m1g1m1t1.1
# 17  A1s2i1s1t1a1n1t1 1r1e1l1a1t1i1o1n1s1h1i1p1 1m1...
# 18  M1a1n1a1g1e1r1 1-1 1e1d2r1 1-1 1d1o1c1u1m1e1n1...
# 19                                     A1d1v1i1s1o1r1
# 20  S1e1n1i1o1r1 1a1c2o1u1n1t1 1e1x1e1c1u1t1i1v1e1...
# 21                 M1a1n1a1g1e1r1 1-1 1i1n1d1i1c1e1s1
# 22  D1i1r1e1c1t1o1r1,1 1s1o1l1u1t1i1o1n1 1c1o1n1s1...
# 23  T1e1a1m1 1l1e1a1d1 1-1 1t1e1c1h1n1i1c1a1l1 1a1...
# 24                                 H1e1a1d1 1c1h1e1f1
# 25           R1e1c1e1p1t1i1o1n1i1s1t1 1f1r1e1s1h1e1r1
# 26  C1h1i1e1f1 1c1u1s1t1o1m1e1r1 1t1r1a1n1s1f1o1r1...
# 27  T1e1a1m1 1m1e1m1b1e1r1 1-1 1w1o1m1e1n1 1e1m1p1...
# 28  Q1u1a1l1i1t1y1 1c1o1n1t1r1o1l1 1s1u1p1e1r1v1i1...
# 29                                   C1o2k1-1l1e1a1d1
# 30                                     M1a1n1a1g1e1r1
# 31  M1a1n1a1g1e1r1 1-1 1c1a1t1e1g1o1r1y1 1(1a1p2a1...
# 32                             M1a1n1a1g1e1r1-1g1t1m1
# 33  A1s2i1s1t1a1n1t1 1m1a1n1a1g1e1r1 1-1 1d1i1g1i1...
# 34                         M1a1n1a1g1e1r1-1 1f1i1c1o1
# 35       P1e1o1p1l1e1 1d1i1r1e1c1t1o1r1,1 1i1n1d1i1a1
# 36                                 S1m1e1 1-1 1d1n1s1
# 37  H1i1r1i1n1g1 1s1e1n1i1o1r1 1m1a1n1a1g1e1r1 1-1...
# 38                               C1o1n1s1u1l1t1a1n1t1
# 39  M1a1n1a1g1e1r1,1 1p1o1l1i1c1y1 1a1n1d1 1s1m1e1...
# 40  B1u1s1i1n1e1s2 1d1i1r1e1c1t1o1r1 1-1 1d1i1g1i1...
# 41               F1a1s1h1i1o1n1 1c1o1n1s1u1l1t1a1n1t1
# 42                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 43                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 44                       V1i1c1e1 1p1r1e1s1i1d1e1n1t1
# 45       R1e1g1i1o1n1a1l1 1s1a1l1e1s1 1m1a1n1a1g1e1r1
# 46                       S1e1n1i1o1r1 1m1a1n1a1g1e1r1
# 47         V1i1c1e1 1p1r1e1s1i1d1e1n1t1-1 1s1a1l1e1s1
# 48  S1e1n1i1o1r1 1p1a1r1t1n1e1r1 1i1n1 1s1t1r1a1t1...
